# %% [markdown]
# # Import Modules & Download required files

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import imutils
from datetime import datetime
import time
import os
import glob
import dlib
import threading
import math
# !pip install pytesseract
import pytesseract
# below installation needed to run pytesseract
# !sudo apt-get install tesseract-ocr

print("Required modules imported")
# create required output directory
# !mkdir output
# !mkdir output/overspeedVehicles
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.8.tar.gz (14 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from pytesseract) (7.1.2)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=f0ace897eb5f4aaec503fdf4574d88f6581ec910af6db3691bc648d6aeb6fd82
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.8
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 37 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 3s (1,651 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Required modules imported

# %%
# !wget https://www.dropbox.com/s/g19fvht674q219r/cars.mp4
# !wget https://www.dropbox.com/s/bkwmskdd10v9vh1/myhaar.xml
print("Required files downloaded")
# Out:
# --2021-12-26 14:50:39--  https://www.dropbox.com/s/g19fvht674q219r/cars.mp4
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/g19fvht674q219r/cars.mp4 [following]
# --2021-12-26 14:50:40--  https://www.dropbox.com/s/raw/g19fvht674q219r/cars.mp4
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com/cd/0/inline/BckP9DvzvhLxyx1nKasFgYJ7fC6PrA2wOkHaeHcqySYV2-Lv33fEg6F-o-tX8NDWDXBIdWUtrYRkhbO0JZ5B0M0Co4i4xWKEoBWOUDGnnoIN9W7k8z3xt9z_KIrBKovwmqzkKz_ymzG1SLRy_U6id6oT/file# [following]
# --2021-12-26 14:50:40--  https://uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com/cd/0/inline/BckP9DvzvhLxyx1nKasFgYJ7fC6PrA2wOkHaeHcqySYV2-Lv33fEg6F-o-tX8NDWDXBIdWUtrYRkhbO0JZ5B0M0Co4i4xWKEoBWOUDGnnoIN9W7k8z3xt9z_KIrBKovwmqzkKz_ymzG1SLRy_U6id6oT/file
# Resolving uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com (uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6035:15::a27d:550f
# Connecting to uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com (uc1bd49a6d1c0256d6597f1cd5a0.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1385458 (1.3M) [video/mp4]
# Saving to: ‘cars.mp4’
#
# cars.mp4            100%[===================>]   1.32M  2.66MB/s    in 0.5s
#
# 2021-12-26 14:50:41 (2.66 MB/s) - ‘cars.mp4’ saved [1385458/1385458]
#
# --2021-12-26 14:50:41--  https://www.dropbox.com/s/bkwmskdd10v9vh1/myhaar.xml
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/bkwmskdd10v9vh1/myhaar.xml [following]
# --2021-12-26 14:50:42--  https://www.dropbox.com/s/raw/bkwmskdd10v9vh1/myhaar.xml
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com/cd/0/inline/BcnD2_Avl4BOI4QY-MJ1XCyfyceWhmdvPMC_rvH65JKr9Xuqni2WrlTeXwk66rOei0fwx9WwyMSOZ1V4aJY-jAFZsYhVBPbFTK6gFdWD1bUROLpXml7pFjqdDScruERHBfVG53dlXf5tdqvxuoyCzQA8/file# [following]
# --2021-12-26 14:50:42--  https://uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com/cd/0/inline/BcnD2_Avl4BOI4QY-MJ1XCyfyceWhmdvPMC_rvH65JKr9Xuqni2WrlTeXwk66rOei0fwx9WwyMSOZ1V4aJY-jAFZsYhVBPbFTK6gFdWD1bUROLpXml7pFjqdDScruERHBfVG53dlXf5tdqvxuoyCzQA8/file
# Resolving uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com (uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6035:15::a27d:550f
# Connecting to uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com (uc2b47b213ae8621efb9dd88edb2.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375639 (367K) [text/plain]
# Saving to: ‘myhaar.xml’
#
# myhaar.xml          100%[===================>] 366.83K  1.04MB/s    in 0.3s
#
# 2021-12-26 14:50:43 (1.04 MB/s) - ‘myhaar.xml’ saved [375639/375639]
#
# Required files downloaded

# %% [markdown]
# # Initialize Vehicle detect and speed estimation model

# %%
video = cv2.VideoCapture('cars.mp4')

WIDTH = 1280
HEIGHT = 720
# myhaar.xml is pretrained model on images of cars from the rear
carCascade = cv2.CascadeClassifier('myhaar.xml')
############################################################################

# function to estimate speed
def estimateSpeed(location1, location2):
  d_pixels = math.sqrt(math.pow(location2[0] - location1[0], 2) + math.pow(location2[1] - location1[1], 2))
  # ppm = location2[2] / carWidht
  ppm = 8.8
  d_meters = d_pixels / ppm
  #print("d_pixels=" + str(d_pixels), "d_meters=" + str(d_meters))
  fps = 18
  speed = d_meters * fps * 3.6
  return speed



# Write output to video file  #########<To create output video file>##########
out = cv2.VideoWriter('/content/output/out.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (WIDTH,HEIGHT))

# dataframe to record overspeeding vehicles
overspeed = {'carID': [], "speed": [], 'date_time': [],'vehicle_plate': 0 }
overspeedDIR = "/content/output/overspeedVehicles/"

# %% [markdown]
# # Function to convert number_plate from image to text

# %%
def get_number_plate(filepath):
  """
  take image file location, scansimage for number plate,
   and return number plate as string
  """
  # importing image
  image = cv2.imread(filepath)
  # converting image to greyscale for faster processing
  grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  # plt.imshow(image)
  # plt.figure()
  # plt.imshow(grey)

  # creating noise in image by blurring it
  blur = cv2.bilateralFilter(grey, 20, 100, 100)
  # plt.imshow(blur)

  edges = cv2.Canny(blur, 15, 100)
  # plt.imshow(edges)

  # finding contours in image
  # there are three arguments in cv.findContours() function
  # first one is source image, second is contour retrieval mode, third is contour approximation method.
  contours, new = cv2.findContours(edges.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE) 
  image_copy = image.copy()
  _ = cv2.drawContours(image_copy, contours, -1, (255,0,255),2)
  # plt.imshow(image_copy)

  # high number of contours found, so sorting to get top 20 max area contours
  contours = sorted(contours, key=cv2.contourArea, reverse=True)[:5] 
  _ = cv2.drawContours(image_copy, contours, -1, (255,0,255),2)
  # plt.imshow(image_copy)

  plate = None

  for contour in contours:
    perimeter = cv2.arcLength(contour, True)
    edges_count = cv2.approxPolyDP(contour, 0.02 * perimeter, True)

    if len(edges_count) == 4:
      x,y,w,h = cv2.boundingRect(contour)
      plate = image[y:y+h, x:x+w]
      break

  if type(plate) == type(None):
    return "unable to detect"

  else:
  # plt.imshow(plate)
  # saving detected number plate
    plate_path = filepath.split('.')
    plate_path[0] = plate_path[0] + "_plateDetected"
    plate_path = '.'.join(plate_path)
    cv2.imwrite(plate_path,plate)
    # decode string from number plate

    # tessdata_dir_config = "/usr/share/tesseract-ocr/4.00/tessdata" #, config=tessdata_dir_config
    car_number = pytesseract.image_to_string(plate, lang = 'eng')
    # splitting to remove unwanted characters
    # print(car_number.split('\n')[0])

    if car_number.split('\n')[0] == '\x0c':
      return "unable to detect"
    else:
      return car_number.split('\n')[0]

# %%
# get_number_plate("/content/numberplate.jpg")

# %% [markdown]
# # Function to detect vehicles & their respective speeds

# %%
def detect_vehicle_speed():


  rectangleColor = (0, 255, 0)
  frameCounter = 0
  currentCarID = 0
  fps = 0

  carTracker = {}
  carNumbers = {}
  carLocation1 = {}
  carLocation2 = {}
  speed = [None] * 3000

  # tracking vehicles from images
  while True:

    start_time = time.time()
    rc, image = video.read()
    if type(image) == type(None):
      break

    image = cv2.resize(image, (WIDTH, HEIGHT))
    resultImage = image.copy()

    frameCounter = frameCounter + 1

    carIDtoDelete = []

    for carID in carTracker.keys():
      trackingQuality = carTracker[carID].update(image)

      if trackingQuality < 15:
        carIDtoDelete.append(carID)

    for carID in carIDtoDelete:
      print ('Removing carID ' + str(carID) + ' from list of trackers.')
      # print ('Removing carID ' + str(carID) + ' previous location.')
      # print ('Removing carID ' + str(carID) + ' current location.')
      carTracker.pop(carID, None)
      carLocation1.pop(carID, None)
      carLocation2.pop(carID, None)

    if not (frameCounter % 10):
      gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
      cars = carCascade.detectMultiScale(gray, 1.1, 13, 18, (24, 24))
      

      for (_x, _y, _w, _h) in cars:
        x = int(_x)
        y = int(_y)
        w = int(_w)
        h = int(_h)

        x_bar = x + 0.5 * w
        y_bar = y + 0.5 * h

        matchCarID = None

        for carID in carTracker.keys():
          trackedPosition = carTracker[carID].get_position()

          t_x = int(trackedPosition.left())
          t_y = int(trackedPosition.top())
          t_w = int(trackedPosition.width())
          t_h = int(trackedPosition.height())

          t_x_bar = t_x + 0.5 * t_w
          t_y_bar = t_y + 0.5 * t_h

          if ((t_x <= x_bar <= (t_x + t_w)) and (t_y <= y_bar <= (t_y + t_h)) and (x <= t_x_bar <= (x + w)) and (y <= t_y_bar <= (y + h))):
            matchCarID = carID

        if matchCarID is None:
          print ('Creating new tracker ' + str(currentCarID))

          tracker = dlib.correlation_tracker()
          tracker.start_track(image, dlib.rectangle(x, y, x + w, y + h))

          carTracker[currentCarID] = tracker
          carLocation1[currentCarID] = [x, y, w, h]

          currentCarID = currentCarID + 1

    #cv2.line(resultImage,(0,480),(1280,480),(255,0,0),5)


    for carID in carTracker.keys():
      trackedPosition = carTracker[carID].get_position()

      t_x = int(trackedPosition.left())
      t_y = int(trackedPosition.top())
      t_w = int(trackedPosition.width())
      t_h = int(trackedPosition.height())

      cv2.rectangle(resultImage, (t_x, t_y), (t_x + t_w, t_y + t_h), rectangleColor, 4)

      # speed estimation
      carLocation2[carID] = [t_x, t_y, t_w, t_h]

    end_time = time.time()

    if not (end_time == start_time):
      fps = 1.0/(end_time - start_time)


    ############################################################################## 
    # GET VEHICLE SPEED
    ##############################################################################
    for i in carLocation1.keys():	
      if frameCounter % 1 == 0:
        [x1, y1, w1, h1] = carLocation1[i]
        [x2, y2, w2, h2] = carLocation2[i]

        # print('previous location: ', str(carLocation1[i]),', current location: ', str(carLocation2[i]))
        carLocation1[i] = [x2, y2, w2, h2]

      # print('new previous location: ', str(carLocation1[i]))
        if [x1, y1, w1, h1] != [x2, y2, w2, h2]:
          if (speed[i] == None or speed[i] == 0) and y1 >= 275 and y1 <= 285:
            speed[i] = estimateSpeed([x1, y1, w1, h1], [x2, y2, w2, h2])

      #if y1 > 275 and y1 < 285:
          if speed[i] != None and y1 >= 180:
            cv2.putText(resultImage, str(int(speed[i])) + " km/hr", (int(x1 + w1/2), int(y1-5)),cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)
            print(f"car ID: {carID}, speed: {speed[i]} KMPH")

            # SETTING SPEED LIMIT OF 60 KMPH FOR OVERSPEEDING
            if speed[i] > 60:

              # saving cropped vehicle image of overspeed vehicle
              cropImg = image[y1:y1+h1, x1:x1+w1]
              loc = overspeedDIR + str(carID) + ".jpg"
              cv2.imwrite(loc, cropImg)

              # calling function to detect number plate
              numberplate = get_number_plate(filepath = loc)


              overspeed['carID'].append(carID)
              overspeed['speed'].append(int(speed[i]))
              overspeed['date_time'].append(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
              overspeed['vehicle_plate'] = numberplate


    # cv2.imshow('result', resultImage)
    # Write the frame into the file 'output.avi'
    out.write(resultImage)


  # if output video is enabled, release by uncommenting below
  out.release()
  video.release()

  cv2.destroyAllWindows()

# %% [markdown]
# # Execution

# %%
detect_vehicle_speed()
# Out:
# Creating new tracker 0
# Creating new tracker 1
# Creating new tracker 2
# Creating new tracker 3
# Removing carID 2 from list of trackers.
# Creating new tracker 4
# Creating new tracker 5
# Removing carID 5 from list of trackers.
# Removing carID 4 from list of trackers.
# Removing carID 3 from list of trackers.
# Creating new tracker 6
# Creating new tracker 7
# Creating new tracker 8
# Removing carID 6 from list of trackers.
# car ID: 8, speed: 66.68056328992098 KMPH
# car ID: 8, speed: 66.68056328992098 KMPH
# car ID: 8, speed: 66.68056328992098 KMPH
# Creating new tracker 9
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# Removing carID 1 from list of trackers.
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# car ID: 9, speed: 66.68056328992098 KMPH
# Creating new tracker 10
# car ID: 10, speed: 66.68056328992098 KMPH
# Removing carID 9 from list of trackers.
# car ID: 10, speed: 66.68056328992098 KMPH
# car ID: 10, speed: 66.68056328992098 KMPH
# car ID: 10, speed: 66.68056328992098 KMPH
# car ID: 10, speed: 66.68056328992098 KMPH
# car ID: 10, speed: 66.68056328992098 KMPH
# Creating new tracker 11
# Creating new tracker 12
# Removing carID 7 from list of trackers.
# Removing carID 8 from list of trackers.
# Creating new tracker 13
# Creating new tracker 14
# Removing carID 11 from list of trackers.
# car ID: 14, speed: 46.57172554066159 KMPH
# car ID: 14, speed: 46.57172554066159 KMPH
# car ID: 14, speed: 46.57172554066159 KMPH
# car ID: 14, speed: 46.57172554066159 KMPH
# car ID: 14, speed: 46.57172554066159 KMPH
# Creating new tracker 15
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# car ID: 15, speed: 46.57172554066159 KMPH
# Removing carID 12 from list of trackers.
# Removing carID 15 from list of trackers.
# Removing carID 14 from list of trackers.
# Removing carID 0 from list of trackers.
# Creating new tracker 16
# Creating new tracker 17
# Creating new tracker 18
# Removing carID 17 from list of trackers.
# Creating new tracker 19
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# Removing carID 13 from list of trackers.
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# car ID: 19, speed: 42.937009407497214 KMPH
# Creating new tracker 20
# Creating new tracker 21
# car ID: 21, speed: 42.937009407497214 KMPH
# car ID: 21, speed: 42.937009407497214 KMPH
# car ID: 21, speed: 42.937009407497214 KMPH
# car ID: 21, speed: 42.937009407497214 KMPH
# car ID: 21, speed: 42.937009407497214 KMPH
# car ID: 21, speed: 42.937009407497214 KMPH
# Removing carID 19 from list of trackers.
# Removing carID 21 from list of trackers.
# car ID: 20, speed: 42.937009407497214 KMPH
# car ID: 20, speed: 42.937009407497214 KMPH
# car ID: 20, speed: 42.937009407497214 KMPH
# car ID: 20, speed: 42.937009407497214 KMPH
# Creating new tracker 22
# Creating new tracker 23
# car ID: 23, speed: 42.937009407497214 KMPH
# Removing carID 20 from list of trackers.
# Removing carID 22 from list of trackers.
# Removing carID 18 from list of trackers.
# Removing carID 23 from list of trackers.
# Creating new tracker 24
# Creating new tracker 25
# Creating new tracker 26
# Removing carID 10 from list of trackers.
# Removing carID 16 from list of trackers.
# Removing carID 24 from list of trackers.
# Removing carID 26 from list of trackers.
# Creating new tracker 27
# Creating new tracker 28
# Creating new tracker 29
# Removing carID 25 from list of trackers.
# Removing carID 28 from list of trackers.
# Creating new tracker 30
# Creating new tracker 31
# Creating new tracker 32
# Removing carID 32 from list of trackers.
# Removing carID 30 from list of trackers.
# Creating new tracker 33
# Creating new tracker 34
# Creating new tracker 35
# Creating new tracker 36
# Creating new tracker 37
# car ID: 37, speed: 0.0 KMPH
# Removing carID 36 from list of trackers.
# car ID: 37, speed: 98.24316265402118 KMPH
# Removing carID 35 from list of trackers.
# Removing carID 37 from list of trackers.
# Creating new tracker 38
# Creating new tracker 39
# Removing carID 34 from list of trackers.
# Removing carID 31 from list of trackers.
# Creating new tracker 40
# Creating new tracker 41
# Creating new tracker 42
# Removing carID 29 from list of trackers.
# car ID: 42, speed: 59.36753432838023 KMPH
# Removing carID 42 from list of trackers.
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# Removing carID 40 from list of trackers.
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# car ID: 41, speed: 59.36753432838023 KMPH
# Removing carID 41 from list of trackers.
# Creating new tracker 43
# Creating new tracker 44
# Creating new tracker 45
# car ID: 45, speed: 59.36753432838023 KMPH
# car ID: 45, speed: 59.36753432838023 KMPH
# car ID: 45, speed: 59.36753432838023 KMPH
# car ID: 45, speed: 59.36753432838023 KMPH
# Removing carID 38 from list of trackers.
# car ID: 45, speed: 59.36753432838023 KMPH
# car ID: 45, speed: 59.36753432838023 KMPH
# Removing carID 33 from list of trackers.
# Removing carID 45 from list of trackers.
# car ID: 44, speed: 59.36753432838023 KMPH
# Removing carID 43 from list of trackers.
# car ID: 44, speed: 59.36753432838023 KMPH
# car ID: 44, speed: 59.36753432838023 KMPH
# car ID: 44, speed: 59.36753432838023 KMPH
# Creating new tracker 46
# Creating new tracker 47
# Creating new tracker 48
# Removing carID 44 from list of trackers.
# Removing carID 27 from list of trackers.
# Removing carID 39 from list of trackers.
# Creating new tracker 49
# Removing carID 46 from list of trackers.
# Removing carID 49 from list of trackers.
# Removing carID 48 from list of trackers.
# Creating new tracker 50
# Creating new tracker 51
# Creating new tracker 52
# Removing carID 47 from list of trackers.
# Removing carID 52 from list of trackers.
# Removing carID 50 from list of trackers.
# Creating new tracker 53
# Creating new tracker 54
# Removing carID 54 from list of trackers.
# Removing carID 51 from list of trackers.
# Creating new tracker 55
# Creating new tracker 56
# Removing carID 56 from list of trackers.
# Creating new tracker 57
# Removing carID 57 from list of trackers.
# Creating new tracker 58
# Removing carID 53 from list of trackers.
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# car ID: 58, speed: 37.547325509183224 KMPH
# Creating new tracker 59
# car ID: 59, speed: 37.547325509183224 KMPH
# car ID: 59, speed: 37.547325509183224 KMPH
# car ID: 59, speed: 37.547325509183224 KMPH
# car ID: 59, speed: 37.547325509183224 KMPH
# car ID: 59, speed: 37.547325509183224 KMPH
# car ID: 59, speed: 37.547325509183224 KMPH
# Removing carID 58 from list of trackers.
# Creating new tracker 60
# Creating new tracker 61
# Removing carID 59 from list of trackers.
# Creating new tracker 62
# Removing carID 62 from list of trackers.
# Creating new tracker 63
# Removing carID 55 from list of trackers.
# Removing carID 60 from list of trackers.
# Creating new tracker 64
# Removing carID 63 from list of trackers.
# Removing carID 64 from list of trackers.
# Creating new tracker 65
# Creating new tracker 66
# Removing carID 66 from list of trackers.
# Creating new tracker 67
# Creating new tracker 68
# Removing carID 65 from list of trackers.
# car ID: 68, speed: 63.34439514822297 KMPH
# car ID: 68, speed: 63.34439514822297 KMPH
# Creating new tracker 69
# Creating new tracker 70
# car ID: 70, speed: 63.34439514822297 KMPH
# Removing carID 70 from list of trackers.
# car ID: 69, speed: 63.34439514822297 KMPH
# car ID: 69, speed: 63.34439514822297 KMPH
# car ID: 69, speed: 63.34439514822297 KMPH
# Removing carID 67 from list of trackers.
# car ID: 69, speed: 63.34439514822297 KMPH
# Removing carID 69 from list of trackers.
# car ID: 68, speed: 63.34439514822297 KMPH
# car ID: 68, speed: 63.34439514822297 KMPH
# car ID: 68, speed: 63.34439514822297 KMPH
# car ID: 68, speed: 63.34439514822297 KMPH
# car ID: 68, speed: 63.34439514822297 KMPH
# Creating new tracker 71
# Creating new tracker 72
# Creating new tracker 73
# Creating new tracker 74
# car ID: 74, speed: 63.34439514822297 KMPH
# car ID: 74, speed: 63.34439514822297 KMPH
# Removing carID 68 from list of trackers.
# Removing carID 73 from list of trackers.
# Removing carID 74 from list of trackers.
# Creating new tracker 75
# Creating new tracker 76
# Removing carID 71 from list of trackers.
# Creating new tracker 77
# Removing carID 72 from list of trackers.
# Removing carID 77 from list of trackers.
# Removing carID 75 from list of trackers.
# Creating new tracker 78
# Creating new tracker 79
# Creating new tracker 80
# Removing carID 78 from list of trackers.
# Creating new tracker 81
# Removing carID 80 from list of trackers.
# Removing carID 79 from list of trackers.
# Removing carID 81 from list of trackers.
# Creating new tracker 82
# Creating new tracker 83
# Creating new tracker 84
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# Removing carID 61 from list of trackers.
# car ID: 84, speed: 36.81818181818182 KMPH
# car ID: 84, speed: 36.81818181818182 KMPH
# Removing carID 84 from list of trackers.
# Creating new tracker 85
# Creating new tracker 86
# Removing carID 86 from list of trackers.
# Removing carID 85 from list of trackers.
# Removing carID 82 from list of trackers.
# Creating new tracker 87
# Creating new tracker 88
# Creating new tracker 89
# Creating new tracker 90
# Creating new tracker 91
# Removing carID 89 from list of trackers.
# car ID: 91, speed: 59.36753432838023 KMPH
# car ID: 91, speed: 59.36753432838023 KMPH
# car ID: 91, speed: 59.36753432838023 KMPH
# Removing carID 90 from list of trackers.
# Creating new tracker 92
# Removing carID 83 from list of trackers.
# Removing carID 91 from list of trackers.
# Removing carID 87 from list of trackers.
# Creating new tracker 93
# Creating new tracker 94
# Creating new tracker 95
# car ID: 95, speed: 0.0 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# Removing carID 93 from list of trackers.
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# car ID: 95, speed: 52.068772069191226 KMPH
# Removing carID 92 from list of trackers.
# Creating new tracker 96
# Creating new tracker 97
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# Removing carID 94 from list of trackers.
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# car ID: 97, speed: 52.068772069191226 KMPH
# Removing carID 97 from list of trackers.
# car ID: 96, speed: 52.068772069191226 KMPH
# Creating new tracker 98
# Creating new tracker 99
# Creating new tracker 100
# Creating new tracker 101
# Creating new tracker 102
# car ID: 102, speed: 52.068772069191226 KMPH
# car ID: 102, speed: 52.068772069191226 KMPH
# car ID: 102, speed: 52.068772069191226 KMPH
# car ID: 102, speed: 52.068772069191226 KMPH
# Removing carID 102 from list of trackers.
# Removing carID 100 from list of trackers.
# Removing carID 96 from list of trackers.
# Removing carID 99 from list of trackers.
# Creating new tracker 103
# Creating new tracker 104
# Creating new tracker 105
# Removing carID 88 from list of trackers.
# Removing carID 103 from list of trackers.
# Removing carID 95 from list of trackers.
# Removing carID 98 from list of trackers.
# Removing carID 104 from list of trackers.
# car ID: 105, speed: 59.36753432838023 KMPH
# car ID: 105, speed: 59.36753432838023 KMPH
# car ID: 105, speed: 59.36753432838023 KMPH
# Removing carID 101 from list of trackers.
# Creating new tracker 106
# Creating new tracker 107
# Creating new tracker 108
# Creating new tracker 109
# Creating new tracker 110
# Creating new tracker 111
# car ID: 111, speed: 59.36753432838023 KMPH
# car ID: 111, speed: 59.36753432838023 KMPH
# car ID: 111, speed: 59.36753432838023 KMPH
# car ID: 111, speed: 59.36753432838023 KMPH
# Removing carID 111 from list of trackers.
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 23.285862770330795 KMPH
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 23.285862770330795 KMPH
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 23.285862770330795 KMPH
# Removing carID 108 from list of trackers.
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 23.285862770330795 KMPH
# Removing carID 107 from list of trackers.
# car ID: 110, speed: 59.36753432838023 KMPH
# car ID: 110, speed: 23.285862770330795 KMPH
# Creating new tracker 112
# Creating new tracker 113
# Creating new tracker 114
# car ID: 114, speed: 59.36753432838023 KMPH
# car ID: 114, speed: 23.285862770330795 KMPH
# car ID: 114, speed: 59.36753432838023 KMPH
# car ID: 114, speed: 23.285862770330795 KMPH
# car ID: 114, speed: 59.36753432838023 KMPH
# car ID: 114, speed: 23.285862770330795 KMPH
# car ID: 114, speed: 59.36753432838023 KMPH
# car ID: 114, speed: 23.285862770330795 KMPH
# car ID: 114, speed: 59.36753432838023 KMPH
# car ID: 114, speed: 23.285862770330795 KMPH
# Removing carID 114 from list of trackers.
# car ID: 113, speed: 59.36753432838023 KMPH
# car ID: 113, speed: 23.285862770330795 KMPH
# car ID: 113, speed: 59.36753432838023 KMPH
# car ID: 113, speed: 23.285862770330795 KMPH
# car ID: 113, speed: 59.36753432838023 KMPH
# car ID: 113, speed: 23.285862770330795 KMPH
# car ID: 113, speed: 59.36753432838023 KMPH
# car ID: 113, speed: 23.285862770330795 KMPH
# Removing carID 106 from list of trackers.
# car ID: 113, speed: 59.36753432838023 KMPH
# car ID: 113, speed: 23.285862770330795 KMPH
# Creating new tracker 115
# Creating new tracker 116
# Creating new tracker 117
# car ID: 117, speed: 59.36753432838023 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# Removing carID 112 from list of trackers.
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# Removing carID 115 from list of trackers.
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 47.150278475641876 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 47.150278475641876 KMPH
# car ID: 117, speed: 23.285862770330795 KMPH
# car ID: 117, speed: 47.150278475641876 KMPH
# Removing carID 105 from list of trackers.
# Creating new tracker 118
# Creating new tracker 119
# car ID: 119, speed: 23.285862770330795 KMPH
# car ID: 119, speed: 47.150278475641876 KMPH
# car ID: 119, speed: 47.150278475641876 KMPH
# car ID: 119, speed: 47.150278475641876 KMPH
# Removing carID 116 from list of trackers.
# Removing carID 119 from list of trackers.
# Removing carID 110 from list of trackers.
# Removing carID 113 from list of trackers.
# Removing carID 109 from list of trackers.
# Creating new tracker 120
# Creating new tracker 121
# Creating new tracker 122
# Creating new tracker 123
# Removing carID 118 from list of trackers.
# car ID: 123, speed: 52.068772069191226 KMPH
# Removing carID 117 from list of trackers.
# Removing carID 123 from list of trackers.
# Creating new tracker 124
# Creating new tracker 125
# Creating new tracker 126
# Removing carID 125 from list of trackers.
# Creating new tracker 127
# Removing carID 124 from list of trackers.
# Removing carID 127 from list of trackers.
# Creating new tracker 128
# Creating new tracker 129
# Creating new tracker 130
# Removing carID 120 from list of trackers.
# Removing carID 126 from list of trackers.
# Removing carID 128 from list of trackers.
# Removing carID 130 from list of trackers.
# Creating new tracker 131
# Creating new tracker 132
# Creating new tracker 133
# Removing carID 122 from list of trackers.
# Removing carID 131 from list of trackers.
# Creating new tracker 134
# Creating new tracker 135
# Removing carID 121 from list of trackers.
# Removing carID 129 from list of trackers.
# Removing carID 135 from list of trackers.
# Creating new tracker 136
# Creating new tracker 137
# Creating new tracker 138
# Creating new tracker 139
# Removing carID 139 from list of trackers.
# Removing carID 136 from list of trackers.
# Removing carID 137 from list of trackers.
# Creating new tracker 140
# Creating new tracker 141
# Removing carID 140 from list of trackers.
# Removing carID 141 from list of trackers.
# Creating new tracker 142
# Creating new tracker 143
# Creating new tracker 144
# Removing carID 132 from list of trackers.
# Removing carID 133 from list of trackers.
# Removing carID 134 from list of trackers.
# Removing carID 142 from list of trackers.
# Removing carID 143 from list of trackers.
# car ID: 144, speed: 31.241263241514734 KMPH
# car ID: 144, speed: 31.241263241514734 KMPH
# car ID: 144, speed: 31.241263241514734 KMPH
# car ID: 144, speed: 31.241263241514734 KMPH
# Removing carID 144 from list of trackers.
# Removing carID 138 from list of trackers.
# Creating new tracker 145
# Creating new tracker 146
# Creating new tracker 147
# Creating new tracker 148
# Creating new tracker 149
# Creating new tracker 150
# Creating new tracker 151
# Removing carID 151 from list of trackers.
# Removing carID 145 from list of trackers.
# Creating new tracker 152
# Creating new tracker 153
# Creating new tracker 154
# Removing carID 146 from list of trackers.
# Removing carID 150 from list of trackers.
# Removing carID 154 from list of trackers.
# car ID: 153, speed: 66.68056328992098 KMPH
# car ID: 153, speed: 66.68056328992098 KMPH
# Creating new tracker 155
# Creating new tracker 156
# Creating new tracker 157
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# Removing carID 156 from list of trackers.
# car ID: 157, speed: 66.68056328992098 KMPH
# Removing carID 149 from list of trackers.
# Removing carID 155 from list of trackers.
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# car ID: 157, speed: 66.68056328992098 KMPH
# Removing carID 153 from list of trackers.
# Creating new tracker 158
# Creating new tracker 159
# Creating new tracker 160
# Creating new tracker 161
# Removing carID 148 from list of trackers.
# Removing carID 152 from list of trackers.
# Creating new tracker 162
# car ID: 162, speed: 42.937009407497214 KMPH
# car ID: 162, speed: 42.937009407497214 KMPH
# Removing carID 158 from list of trackers.
# car ID: 162, speed: 42.937009407497214 KMPH
# Removing carID 157 from list of trackers.
# car ID: 162, speed: 53.60808191197472 KMPH
# car ID: 162, speed: 53.60808191197472 KMPH
# car ID: 162, speed: 53.60808191197472 KMPH
# car ID: 162, speed: 53.60808191197472 KMPH
# car ID: 162, speed: 53.60808191197472 KMPH
# car ID: 162, speed: 53.60808191197472 KMPH
# Removing carID 160 from list of trackers.
# car ID: 162, speed: 53.60808191197472 KMPH
# Creating new tracker 163
# Creating new tracker 164
# car ID: 164, speed: 53.60808191197472 KMPH
# car ID: 164, speed: 53.60808191197472 KMPH
# Removing carID 159 from list of trackers.
# car ID: 164, speed: 53.60808191197472 KMPH
# car ID: 164, speed: 53.60808191197472 KMPH
# car ID: 164, speed: 53.60808191197472 KMPH
# car ID: 164, speed: 53.60808191197472 KMPH
# Removing carID 163 from list of trackers.
# car ID: 164, speed: 53.60808191197472 KMPH
# car ID: 164, speed: 53.60808191197472 KMPH
# Removing carID 161 from list of trackers.
# Creating new tracker 165
# Creating new tracker 166
# Creating new tracker 167
# Removing carID 162 from list of trackers.
# Removing carID 164 from list of trackers.
# Creating new tracker 168
# Creating new tracker 169
# Creating new tracker 170
# Removing carID 165 from list of trackers.
# Removing carID 167 from list of trackers.
# Removing carID 168 from list of trackers.
# Creating new tracker 171
# Creating new tracker 172
# Removing carID 171 from list of trackers.
# Removing carID 172 from list of trackers.
# Creating new tracker 173
# Creating new tracker 174
# Creating new tracker 175
# Creating new tracker 176
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# car ID: 176, speed: 52.068772069191226 KMPH
# Removing carID 176 from list of trackers.
# Creating new tracker 177
# Creating new tracker 178
# car ID: 178, speed: 52.068772069191226 KMPH
# car ID: 178, speed: 0.0 KMPH
# Removing carID 147 from list of trackers.
# car ID: 178, speed: 52.068772069191226 KMPH
# car ID: 178, speed: 69.46840651787133 KMPH
# car ID: 178, speed: 52.068772069191226 KMPH
# car ID: 178, speed: 69.46840651787133 KMPH
# Removing carID 174 from list of trackers.
# car ID: 178, speed: 52.068772069191226 KMPH
# car ID: 178, speed: 69.46840651787133 KMPH
# Removing carID 170 from list of trackers.
# Removing carID 173 from list of trackers.
# car ID: 178, speed: 69.46840651787133 KMPH
# car ID: 178, speed: 69.46840651787133 KMPH
# Removing carID 178 from list of trackers.
# car ID: 177, speed: 69.46840651787133 KMPH
# car ID: 177, speed: 69.46840651787133 KMPH
# car ID: 177, speed: 69.46840651787133 KMPH
# Removing carID 175 from list of trackers.
# car ID: 177, speed: 69.46840651787133 KMPH
# Creating new tracker 179
# Creating new tracker 180
# Creating new tracker 181
# Creating new tracker 182
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# car ID: 182, speed: 69.46840651787133 KMPH
# Removing carID 179 from list of trackers.
# Creating new tracker 183
# Creating new tracker 184
# Creating new tracker 185
# Removing carID 182 from list of trackers.
# Removing carID 180 from list of trackers.
# Removing carID 184 from list of trackers.
# Removing carID 185 from list of trackers.
# Creating new tracker 186
# Creating new tracker 187
# Creating new tracker 188
# Removing carID 188 from list of trackers.
# Creating new tracker 189
# Creating new tracker 190
# Removing carID 187 from list of trackers.
# Removing carID 181 from list of trackers.
# Creating new tracker 191
# Creating new tracker 192
# Removing carID 186 from list of trackers.
# Creating new tracker 193
# Removing carID 177 from list of trackers.
# Removing carID 190 from list of trackers.
# Creating new tracker 194
# Creating new tracker 195
# Removing carID 193 from list of trackers.
# Creating new tracker 196
# Creating new tracker 197
# Creating new tracker 198
# Removing carID 192 from list of trackers.
# Removing carID 197 from list of trackers.
# Creating new tracker 199
# Removing carID 196 from list of trackers.
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# Removing carID 166 from list of trackers.
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# car ID: 199, speed: 63.34439514822297 KMPH
# Creating new tracker 200
# car ID: 200, speed: 63.34439514822297 KMPH
# car ID: 200, speed: 63.34439514822297 KMPH
# car ID: 200, speed: 63.34439514822297 KMPH
# car ID: 200, speed: 63.34439514822297 KMPH
# car ID: 200, speed: 63.34439514822297 KMPH
# car ID: 200, speed: 63.34439514822297 KMPH
# Removing carID 195 from list of trackers.
# Removing carID 198 from list of trackers.
# Creating new tracker 201
# Creating new tracker 202
# Removing carID 194 from list of trackers.
# Removing carID 199 from list of trackers.
# Removing carID 200 from list of trackers.
# Removing carID 201 from list of trackers.
# Creating new tracker 203
# Creating new tracker 204
# Creating new tracker 205
# Creating new tracker 206
# Creating new tracker 207
# Creating new tracker 208
# Removing carID 208 from list of trackers.
# Removing carID 169 from list of trackers.
# Removing carID 202 from list of trackers.
# Removing carID 204 from list of trackers.
# Removing carID 206 from list of trackers.
# Removing carID 183 from list of trackers.
# Creating new tracker 209
# Creating new tracker 210
# Creating new tracker 211
# Creating new tracker 212
# Creating new tracker 213
# Creating new tracker 214
# Removing carID 203 from list of trackers.
# Removing carID 212 from list of trackers.
# Removing carID 214 from list of trackers.
# Creating new tracker 215
# Creating new tracker 216
# Removing carID 209 from list of trackers.
# Removing carID 211 from list of trackers.
# Creating new tracker 217
# Creating new tracker 218
# Creating new tracker 219
# Creating new tracker 220
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# Removing carID 219 from list of trackers.
# car ID: 220, speed: 52.068772069191226 KMPH
# Removing carID 215 from list of trackers.
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# car ID: 220, speed: 52.068772069191226 KMPH
# Creating new tracker 221
# Creating new tracker 222
# car ID: 222, speed: 52.068772069191226 KMPH
# car ID: 222, speed: 52.068772069191226 KMPH
# Removing carID 189 from list of trackers.
# Removing carID 191 from list of trackers.
# car ID: 222, speed: 52.068772069191226 KMPH
# Removing carID 222 from list of trackers.
# car ID: 221, speed: 52.068772069191226 KMPH
# Removing carID 217 from list of trackers.
# car ID: 221, speed: 52.068772069191226 KMPH
# Removing carID 76 from list of trackers.
# car ID: 221, speed: 52.068772069191226 KMPH
# car ID: 221, speed: 52.068772069191226 KMPH
# Removing carID 216 from list of trackers.
# Removing carID 210 from list of trackers.
# Creating new tracker 223
# Creating new tracker 224
# Creating new tracker 225
# Removing carID 221 from list of trackers.
# Creating new tracker 226
# Creating new tracker 227
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# Removing carID 205 from list of trackers.
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# car ID: 227, speed: 36.81818181818182 KMPH
# Removing carID 223 from list of trackers.
# Creating new tracker 228
# Creating new tracker 229
# Creating new tracker 230
# Creating new tracker 231
# Creating new tracker 232
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# Removing carID 227 from list of trackers.
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# car ID: 232, speed: 36.81818181818182 KMPH
# Removing carID 220 from list of trackers.
# Removing carID 226 from list of trackers.
# Creating new tracker 233
# Creating new tracker 234
# Removing carID 231 from list of trackers.
# Removing carID 234 from list of trackers.
# Creating new tracker 235
# Creating new tracker 236
# Creating new tracker 237
# Creating new tracker 238
# Removing carID 225 from list of trackers.
# Removing carID 230 from list of trackers.
# Removing carID 235 from list of trackers.
# Creating new tracker 239
# Creating new tracker 240
# Creating new tracker 241
# Creating new tracker 242
# Removing carID 236 from list of trackers.
# Removing carID 237 from list of trackers.
# Removing carID 241 from list of trackers.
# Removing carID 218 from list of trackers.
# Removing carID 240 from list of trackers.
# Creating new tracker 243
# Creating new tracker 244
# Creating new tracker 245
# Creating new tracker 246
# Creating new tracker 247
# Creating new tracker 248
# Removing carID 224 from list of trackers.
# Removing carID 238 from list of trackers.
# Removing carID 246 from list of trackers.
# Removing carID 239 from list of trackers.
# car ID: 248, speed: 83.31003531070597 KMPH
# car ID: 248, speed: 83.31003531070597 KMPH
# Removing carID 247 from list of trackers.
# Creating new tracker 249
# Creating new tracker 250
# Creating new tracker 251
# Creating new tracker 252
# Creating new tracker 253
# Creating new tracker 254
# Removing carID 254 from list of trackers.
# Removing carID 245 from list of trackers.
# Removing carID 243 from list of trackers.
# Removing carID 248 from list of trackers.
# Removing carID 253 from list of trackers.
# Removing carID 249 from list of trackers.
# Creating new tracker 255
# Creating new tracker 256
# Creating new tracker 257
# Creating new tracker 258
# Removing carID 250 from list of trackers.
# Removing carID 251 from list of trackers.
# Removing carID 228 from list of trackers.
# Removing carID 233 from list of trackers.
# Removing carID 242 from list of trackers.
# Removing carID 252 from list of trackers.
# Removing carID 256 from list of trackers.
# Removing carID 257 from list of trackers.
# Removing carID 258 from list of trackers.
# Removing carID 244 from list of trackers.
# Removing carID 255 from list of trackers.
# Creating new tracker 259
# Creating new tracker 260
# Creating new tracker 261
# Creating new tracker 262
# Creating new tracker 263
# Creating new tracker 264
# Creating new tracker 265
# Creating new tracker 266
# Creating new tracker 267
# Removing carID 229 from list of trackers.
# Removing carID 262 from list of trackers.
# Creating new tracker 268
# Creating new tracker 269
# Creating new tracker 270
# Creating new tracker 271
# Removing carID 264 from list of trackers.
# Removing carID 266 from list of trackers.
# Removing carID 265 from list of trackers.
# Removing carID 259 from list of trackers.
# car ID: 271, speed: 10.413754413838246 KMPH
# car ID: 271, speed: 10.413754413838246 KMPH
# Removing carID 261 from list of trackers.
# car ID: 271, speed: 10.413754413838246 KMPH
# Removing carID 260 from list of trackers.
# Creating new tracker 272
# Creating new tracker 273
# Creating new tracker 274
# Creating new tracker 275
# car ID: 275, speed: 10.413754413838246 KMPH
# Removing carID 263 from list of trackers.
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# Removing carID 267 from list of trackers.
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# car ID: 275, speed: 10.413754413838246 KMPH
# Removing carID 271 from list of trackers.
# Removing carID 275 from list of trackers.
# Creating new tracker 276
# Creating new tracker 277
# Creating new tracker 278
# Creating new tracker 279
# Creating new tracker 280
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# Removing carID 232 from list of trackers.
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# car ID: 280, speed: 10.413754413838246 KMPH
# Removing carID 268 from list of trackers.
# Removing carID 269 from list of trackers.
# Removing carID 280 from list of trackers.
# car ID: 279, speed: 10.413754413838246 KMPH
# Removing carID 279 from list of trackers.
# car ID: 278, speed: 10.413754413838246 KMPH
# car ID: 278, speed: 10.413754413838246 KMPH
# car ID: 278, speed: 10.413754413838246 KMPH
# Removing carID 273 from list of trackers.
# car ID: 278, speed: 10.413754413838246 KMPH
# car ID: 278, speed: 10.413754413838246 KMPH
# Removing carID 276 from list of trackers.
# car ID: 278, speed: 10.413754413838246 KMPH
# Creating new tracker 281
# Creating new tracker 282
# Creating new tracker 283
# Creating new tracker 284
# Creating new tracker 285
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# Removing carID 283 from list of trackers.
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# car ID: 285, speed: 10.413754413838246 KMPH
# Removing carID 272 from list of trackers.
# Creating new tracker 286
# Creating new tracker 287
# car ID: 287, speed: 10.413754413838246 KMPH
# car ID: 287, speed: 10.413754413838246 KMPH
# car ID: 287, speed: 10.413754413838246 KMPH
# car ID: 287, speed: 10.413754413838246 KMPH
# car ID: 287, speed: 10.413754413838246 KMPH
# car ID: 287, speed: 10.413754413838246 KMPH
# Removing carID 287 from list of trackers.
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# Removing carID 277 from list of trackers.
# Removing carID 281 from list of trackers.
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# Removing carID 278 from list of trackers.
# car ID: 286, speed: 10.413754413838246 KMPH
# car ID: 286, speed: 65.86236588272106 KMPH
# Creating new tracker 288
# Creating new tracker 289
# car ID: 289, speed: 10.413754413838246 KMPH
# car ID: 289, speed: 65.86236588272106 KMPH
# car ID: 289, speed: 10.413754413838246 KMPH
# car ID: 289, speed: 65.86236588272106 KMPH
# car ID: 289, speed: 10.413754413838246 KMPH
# car ID: 289, speed: 65.86236588272106 KMPH
# Removing carID 213 from list of trackers.
# car ID: 289, speed: 65.86236588272106 KMPH
# Removing carID 285 from list of trackers.
# Removing carID 282 from list of trackers.
# Creating new tracker 290
# Creating new tracker 291
# Creating new tracker 292
# Creating new tracker 293
# Removing carID 270 from list of trackers.
# Removing carID 290 from list of trackers.
# Removing carID 291 from list of trackers.
# Creating new tracker 294
# Removing carID 284 from list of trackers.
# Removing carID 286 from list of trackers.
# Removing carID 294 from list of trackers.
# Creating new tracker 295
# Creating new tracker 296
# Creating new tracker 297
# Creating new tracker 298
# Removing carID 274 from list of trackers.
# Removing carID 292 from list of trackers.
# Removing carID 295 from list of trackers.
# Removing carID 298 from list of trackers.
# Removing carID 293 from list of trackers.
# Removing carID 296 from list of trackers.
# Removing carID 297 from list of trackers.
# Removing carID 288 from list of trackers.
# Creating new tracker 299
# Creating new tracker 300
# Creating new tracker 301
# Creating new tracker 302
# Creating new tracker 303
# Creating new tracker 304
# Removing carID 289 from list of trackers.
# Creating new tracker 305
# Removing carID 300 from list of trackers.
# Removing carID 299 from list of trackers.
# Removing carID 303 from list of trackers.
# Creating new tracker 306
# Creating new tracker 307
# Removing carID 307 from list of trackers.
# Removing carID 304 from list of trackers.
# Creating new tracker 308
# Creating new tracker 309

# %% [markdown]
# # Storing overspeed vehicles data in csv file

# %%
# overspeed_dataframe = pd.DataFrame(overspeed).drop_duplicates(keep = 'last')
overspeed_dataframe = pd.DataFrame(overspeed).groupby('carID').tail(1).reset_index(drop = True)
overspeed_dataframe.to_csv("/content/output/overspeedinglogs.csv", index = False)
overspeed_dataframe
# Out:
#     carID  speed            date_time     vehicle_plate
# 0       8     66  2021-12-26 14:52:39  unable to detect
# 1       9     66  2021-12-26 14:52:41  unable to detect
# 2      10     66  2021-12-26 14:52:43  unable to detect
# 3      37     98  2021-12-26 14:52:55  unable to detect
# 4      70     63  2021-12-26 14:53:16  unable to detect
# 5      69     63  2021-12-26 14:53:16  unable to detect
# 6      68     63  2021-12-26 14:53:17  unable to detect
# 7      74     63  2021-12-26 14:53:18  unable to detect
# 8     153     66  2021-12-26 14:53:55  unable to detect
# 9     157     66  2021-12-26 14:53:58  unable to detect
# 10    178     69  2021-12-26 14:54:10  unable to detect
# 11    177     69  2021-12-26 14:54:11  unable to detect
# 12    182     69  2021-12-26 14:54:12  unable to detect
# 13    199     63  2021-12-26 14:54:29  unable to detect
# 14    200     63  2021-12-26 14:54:30  unable to detect
# 15    248     83  2021-12-26 14:54:56  unable to detect
# 16    286     65  2021-12-26 14:55:18  unable to detect
# 17    289     65  2021-12-26 14:55:19  unable to detect

# %%
# import os
# import zipfile
# zf = zipfile.ZipFile("output.zip", "w")
# for dirname, subdirs, files in os.walk(r"/content/output"):
#     zf.write(dirname)
#     for filename in files:
#         zf.write(os.path.join(dirname, filename))
# zf.close()
